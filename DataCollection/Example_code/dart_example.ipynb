# %% [markdown]
# # DATA EXTRACT

# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname("Financial"))))

# %%
dt.api_key()
# Out:
#         api_key1 ='7db60698e63bd621a006025500fe0436ee65cb47'
#
#         api_key2 = 'fe6d5fea0efcad8f5ce367a096624b9a2213bc0d'
#
#         api_key3 = '2f4e65c96c0399bb2a76d81e45889ac98395998d'
#
#         api_key4 = '3b85edb9e9282fe585038018c3556d9d4b7fb490'

# %%
dt.load_finstats("7db60698e63bd621a006025500fe0436ee65cb47")

# %%
dt.cleansed_finstats.to_excel("KOREA_1Q-3Q.xlsx", index=False)

# %%
dt.information()
# Out:
#         A description of the function is given below.
#
#         The main class within the library is dart_extract.
#
#         api_key() is a function that informs the api key.
#
#         extract_finstate() is a function that extracts data.
#
#         load_finstate() is a function that saves data.

# %% [markdown]
# # DART INFORMATION

# %%
import OpenDartReader
import pandas as pd
from tqdm import tqdm
dart = OpenDartReader("7db60698e63bd621a006025500fe0436ee65cb47")

# %%
df = pd.DataFrame()

# %%
korea_df = pd.read_excel("3rd_data/tb_hb_kor_plcfi_d.xlsx")

# %%
korea_symbol_lst = list(set(korea_df["lstng_cd"]))

# %%
for symbol in tqdm(korea_symbol_lst):
    df = df.append(dart.company(str(symbol)), ignore_index=True)
# Out:
#   0%|          | 0/1554 [00:00<?, ?it/s]C:\Users\user\AppData\Local\Temp\ipykernel_42980\2998021728.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dart.company(str(symbol)), ignore_index=True)
#   0%|          | 1/1554 [00:00<03:25,  7.54it/s]C:\Users\user\AppData\Local\Temp\ipykernel_42980\2998021728.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dart.company(str(symbol)), ignore_index=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_42980\2998021728.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dart.company(str(symbol)), ignore_index=True)
# ...

# %%
df.to_excel("한국_3차년도_재무정보_일반.xlsx", index=False)
